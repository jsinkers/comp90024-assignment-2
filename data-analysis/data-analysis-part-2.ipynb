# %%
import itertools
import json
import os

import pandas as pd
import geopandas as gpd
import ijson
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %% [markdown]
# # Assigning tweets to an SA2
#
# ## Loading SA2 data

# %%
sa2_data = "../data/1270055001_sa2_2016_aust_shape.zip"

sa2_df = gpd.read_file(sa2_data)
# filter to only include melbourne
sa2_df = sa2_df[sa2_df['GCC_NAME16'] == 'Greater Melbourne']
sa2_df
# Out:
#     SA2_MAIN16 SA2_5DIG16         SA2_NAME16 SA3_CODE16            SA3_NAME16  \
# 682  206011105      21105          Brunswick      20601    Brunswick - Coburg
# 683  206011106      21106     Brunswick East      20601    Brunswick - Coburg
# 684  206011107      21107     Brunswick West      20601    Brunswick - Coburg
# 685  206011108      21108             Coburg      20601    Brunswick - Coburg
# 686  206011109      21109  Pascoe Vale South      20601    Brunswick - Coburg
# ..         ...        ...                ...        ...                   ...
# 986  214021381      21381        Mount Eliza      21402  Mornington Peninsula
# 987  214021382      21382       Mount Martha      21402  Mornington Peninsula
# 988  214021383      21383       Point Nepean      21402  Mornington Peninsula
# 989  214021384      21384   Rosebud - McCrae      21402  Mornington Peninsula
# 990  214021385      21385         Somerville      21402  Mornington Peninsula
#
#     SA4_CODE16            SA4_NAME16 GCC_CODE16         GCC_NAME16 STE_CODE16  \
# 682        206     Melbourne - Inner      2GMEL  Greater Melbourne          2
# 683        206     Melbourne - Inner      2GMEL  Greater Melbourne          2
# 684        206     Melbourne - Inner      2GMEL  Greater Melbourne          2
# 685        206     Melbourne - Inner      2GMEL  Greater Melbourne          2
# 686        206     Melbourne - Inner      2GMEL  Greater Melbourne          2
# ..         ...                   ...        ...                ...        ...
# 986        214  Mornington Peninsula      2GMEL  Greater Melbourne          2
# 987        214  Mornington Peninsula      2GMEL  Greater Melbourne          2
# 988        214  Mornington Peninsula      2GMEL  Greater Melbourne          2
# 989        214  Mornington Peninsula      2GMEL  Greater Melbourne          2
# 990        214  Mornington Peninsula      2GMEL  Greater Melbourne          2
#
#     STE_NAME16  AREASQKM16                                           geometry
# 682   Victoria      5.1425  POLYGON ((144.94974 -37.76277, 144.95003 -37.7...
# 683   Victoria      2.1680  POLYGON ((144.97340 -37.76204, 144.97335 -37.7...
# 684   Victoria      3.1795  POLYGON ((144.93407 -37.75969, 144.93405 -37.7...
# 685   Victoria      6.9346  POLYGON ((144.94847 -37.73951, 144.94878 -37.7...
# 686   Victoria      2.9887  POLYGON ((144.93264 -37.74226, 144.93251 -37.7...
# ..         ...         ...                                                ...
# 986   Victoria     23.2077  POLYGON ((145.07201 -38.18710, 145.07216 -38.1...
# 987   Victoria     30.2094  POLYGON ((145.02584 -38.25242, 145.02616 -38.2...
# 988   Victoria     67.1875  MULTIPOLYGON (((144.73141 -38.35025, 144.73147...
# 989   Victoria     23.7957  POLYGON ((144.87372 -38.36268, 144.87388 -38.3...
# 990   Victoria    117.3540  POLYGON ((145.09285 -38.23093, 145.09924 -38.2...
#
# [309 rows x 13 columns]

# %% [markdown]
# ## Determining tweet location

# %%
from shapely.geometry import shape, Point

sa2_main16_df = sa2_df[['SA2_MAIN16', 'geometry']]


# return the SA2 main code for 2016 boundaries
def get_sa2_main16(coordinates):
    point = Point([coordinates['longitude'], coordinates['latitude']])
    # check if point falls in cell
    row_filter = sa2_main16_df.apply(lambda row: row['geometry'].contains(point) or row['geometry'].intersects(point), axis=1)
    return sa2_main16_df[row_filter]['SA2_MAIN16'].iloc[0]

# %%
test_point = sa2_main16_df['geometry'].iloc[0].representative_point()
lon, lat = test_point.coords[0]

# %%
get_sa2_main16({"latitude": lat, "longitude":lon})
# Out:
# '206011105'

# %%
# Test the correct code produced for a representative point in each region
index = 50
test_point = sa2_main16_df['geometry'].iloc[index].representative_point()
lon, lat = test_point.coords[0]
out_sa2_main16 = get_sa2_main16({"latitude": lat, "longitude":lon})
print(f"Output: {out_sa2_main16}")
print(f"Expected: {sa2_main16_df['SA2_MAIN16'].iloc[index]}")
# Out:
# Output: 207011155
# Expected: 207011155

# %% [markdown]
# # Language Spoken at home

# %%
language_sa2_data = '..\data\SA2-P13_Language_Spoken_at_Home_by_Sex-Census_2016.json\sa2_p13_lang_spoken_at_home_by_sex_census_2016-6394559813018131150.json'
#language_sa2_df = pd.read_json(language_sa2_data, index='features')
lang_dicts = []
with open(language_sa2_data) as f:
    data_points = ijson.items(f, 'features.item.properties')
    lang_dicts = list(data_points)

lang_df = pd.DataFrame(lang_dicts)
lang_df
# Out:
#             sa2_name16 sa2_main16  tot_p  lang_spoken_home_ns_p  spks_eng_on_p
# 0          Collingwood  206071141   8619                   1073           5112
# 1    Prahran - Windsor  206061136  19768                   1864          13354
# 2             Hadfield  210031440   5613                    291           2741
# 3      Sunbury - South  210041241  26335                   1224          22708
# 4              Sunbury  210041240  12576                    539          10933
# ..                 ...        ...    ...                    ...            ...
# 304           Flinders  214021378   5269                    357           4697
# 305  Hastings - Somers  214021379  21797                   1270          19743
# 306         Mornington  214021380  23344                   1066          20838
# 307        Mount Eliza  214021381  17475                    568          15546
# 308         Somerville  214021385  17709                    852          16150
#
# [309 rows x 5 columns]

# %% [markdown]
# - determine statistics
# - lang_spoken_home_ns_p: this gives people who didn't report if they speak another language at home.
# - let's assume that the number of people who do so are randomly distributed
# - then the people who reported speaking a language is num_reported = tot_p - lang_spoken_home_ns_p
# - the proportion of people who speak a language other than English is then 1-spks_eng_on_p/(num_reported)

# %%
lang_df['num_reported'] = lang_df['tot_p'] - lang_df['lang_spoken_home_ns_p']
lang_df['prop_spk_english_only'] = lang_df['spks_eng_on_p']/lang_df['num_reported']
lang_df['prop_spk_other_lang'] = 1 - lang_df['prop_spk_english_only']

# %% [markdown]
# Let's look at the areas with the lowest proportion of people who speak English only:

# %%
lang_df.sort_values(by='prop_spk_other_lang').head(10)
# Out:
#                    sa2_name16 sa2_main16  tot_p  lang_spoken_home_ns_p  \
# 219         Bunyip - Garfield  212011288   8467                    526
# 305         Hastings - Somers  214021379  21797                   1270
# 117  Panton Hill - St Andrews  209031212   5003                    369
# 153            Riddells Creek  210021234   3882                    121
# 122               Hurstbridge  209031210   3377                    106
# 308                Somerville  214021385  17709                    852
# 217              Yarra Valley  211051286  15901                    955
# 304                  Flinders  214021378   5269                    357
# 203  Healesville - Yarra Glen  211051276  13661                    812
# 154                    Romsey  210021235   9197                    642
#
#      spks_eng_on_p  num_reported  prop_spk_english_only  prop_spk_other_lang
# 219           7679          7941               0.967007             0.032993
# 305          19743         20527               0.961806             0.038194
# 117           4452          4634               0.960725             0.039275
# 153           3609          3761               0.959585             0.040415
# 122           3134          3271               0.958117             0.041883
# 308          16150         16857               0.958059             0.041941
# 217          14317         14946               0.957915             0.042085
# 304           4697          4912               0.956230             0.043770
# 203          12260         12849               0.954160             0.045840
# 154           8160          8555               0.953828             0.046172

# %% [markdown]
# This seems reasonable. Now let's look at the areas with the highest proportion of people who do not only speak English

# %%
lang_df.sort_values(by='prop_spk_other_lang').dropna().tail(10)
# Out:
#                    sa2_name16 sa2_main16  tot_p  lang_spoken_home_ns_p  \
# 233                 Dandenong  212041311  31369                   2840
# 251                  Cairnlea  213011329   9732                    377
# 232             Clayton South  212041310  12857                    601
# 53                  Melbourne  206041122  57734                  10183
# 166  Campbellfield - Coolaroo  210051243  16201                   1221
# 162            Meadow Heights  210051247  14839                    938
# 240          Springvale South  212041318  12690                    524
# 264            Sunshine North  213011337  11739                    597
# 262         St Albans - South  213011335  17796                   1491
# 239                Springvale  212041317  21958                   1238
#
#      spks_eng_on_p  num_reported  prop_spk_english_only  prop_spk_other_lang
# 233           7677         28529               0.269095             0.730905
# 251           2517          9355               0.269054             0.730946
# 232           3276         12256               0.267298             0.732702
# 53           12602         47551               0.265021             0.734979
# 166           3863         14980               0.257877             0.742123
# 162           3492         13901               0.251205             0.748795
# 240           2885         12166               0.237136             0.762864
# 264           2616         11142               0.234787             0.765213
# 262           3427         16305               0.210181             0.789819
# 239           3809         20720               0.183832             0.816168

# %% [markdown]
# This also seems reasonable

# %% [markdown]
# # SEIFA

# %%
seifa_sa2_data = '..\data\ABS_-_Socio-Economic_Indexes_for_Areas__SEIFA__-_The_Index_of_Relative_Socio-economic_Advantage_and_Disadvantage__SA2__2016.json\sa2_seifa_irsad_2016-8012956430373350930.json'
#seifa_sa2_df = pd.read_json(seifa_sa2_data, index='features')
seifa_dicts = []
with open(seifa_sa2_data) as f:
    data_points = ijson.items(f, 'features.item.properties')
    seifa_dicts = list(data_points)

seifa_df = pd.DataFrame(seifa_dicts)
# Out:
#      usual_res_pop  state_rank ur_pop_wthout_sa1_level_score_pc state  \
# 0            19160         142                             0.05   VIC
# 1            15053         164                             0.13   VIC
# 2            19714         415                             0.00   VIC
# 3             8513         215                             0.00   VIC
# 4             5604          95                             0.07   VIC
# ..             ...         ...                              ...   ...
# 300          17888         435                             0.00   VIC
# 301          18548         366                             0.02   VIC
# 302          17123         195                             0.02   VIC
# 303          20943          72                             4.10   VIC
# 304          18089         231                             0.00   VIC
#
#      state_percentile  state_decile  max_sa1_score_in_area         sa2_name16  \
# 0                  32             4                   1040     Altona Meadows
# 1                  37             4                   1075    Cranbourne West
# 2                  92            10                   1162  Prahran - Windsor
# 3                  48             5                   1181        Collingwood
# 4                  21             3                    996           Hadfield
# ..                ...           ...                    ...                ...
# 300                96            10                   1185        Mount Eliza
# 301                81             9                   1155       Mount Martha
# 302                43             5                   1139       Point Nepean
# 303                16             2                   1072   Rosebud - McCrae
# 304                51             6                   1098         Somerville
#
#      national_percentile  irsad_score  national_decile  national_rank  \
# 0                     37          966                4            799
# 1                     41          976                5            891
# 2                     90         1106                9           1965
# 3                     51          999                6           1114
# 4                     28          947                3            604
# ..                   ...          ...              ...            ...
# 300                   94         1121               10           2033
# 301                   82         1076                9           1773
# 302                   48          992                5           1042
# 303                   23          934                3            489
# 304                   54         1005                6           1174
#
#     sa2_main16  min_sa1_score_in_area
# 0    213021342                    875
# 1    212031304                    889
# 2    206061136                    841
# 3    206071141                    516
# 4    210031440                    850
# ..         ...                    ...
# 300  214021381                    953
# 301  214021382                    992
# 302  214021383                    885
# 303  214021384                    801
# 304  214021385                    926
#
# [305 rows x 14 columns]

# %%
seifa_df.sort_values(by='state_rank', ascending=False)
# Out:
#      usual_res_pop  state_rank ur_pop_wthout_sa1_level_score_pc state  \
# 20            4962         454                             0.10   VIC
# 65           16326         453                             0.00   VIC
# 69           16319         452                             0.00   VIC
# 54           13050         451                             0.00   VIC
# 85           22695         450                             0.00   VIC
# ..             ...         ...                              ...   ...
# 153          14842           7                             0.00   VIC
# 215          11306           6                             0.03   VIC
# 27              58           5                             0.00   VIC
# 155          16122           3                             0.16   VIC
# 152          13305           1                             0.03   VIC
#
#      state_percentile  state_decile  max_sa1_score_in_area  \
# 20                100            10                   1199
# 65                100            10                   1201
# 69                100            10                   1180
# 54                100            10                   1196
# 85                 99            10                   1189
# ..                ...           ...                    ...
# 153                 2             1                    905
# 215                 2             1                    915
# 27                  2             1                    838
# 155                 1             1                    887
# 152                 1             1                    903
#
#                            sa2_name16  national_percentile  irsad_score  \
# 20                     East Melbourne                   99         1160
# 65                   Glen Iris - East                   99         1154
# 69   Surrey Hills (West) - Canterbury                   98         1147
# 54                             Toorak                   97         1144
# 85                    Brighton (Vic.)                   97         1144
# ..                                ...                  ...          ...
# 153                    Meadow Heights                    4          846
# 215                           Doveton                    3          844
# 27                           Braeside                    3          838
# 155          Campbellfield - Coolaroo                    3          828
# 152                      Broadmeadows                    2          819
#
#      national_decile  national_rank sa2_main16  min_sa1_score_in_area
# 20                10           2151  206041119                   1081
# 65                10           2142  207011150                   1105
# 69                10           2127  207011155                   1106
# 54                10           2119  206061138                   1098
# 85                10           2118  208011169                    937
# ..               ...            ...        ...                    ...
# 153                1             71  210051247                    734
# 215                1             64  212021295                    775
# 27                 1             58  208031184                    838
# 155                1             49  210051243                    754
# 152                1             43  210051242                    557
#
# [305 rows x 14 columns]

# %% [markdown]
# # Perform tweet analysis
#
# - determine tweet SA2 code
# - perform sentiment analysis
# - join with language and seifa
# - draw some plots
